# %% [markdown]
# # 05 | Data Quality
#
# This notebook runs the Great Expectations checkpoint and records summary results.

# %%
# Parameters
source = "fivethirtyeight"
dataset = "recent_grads,bechdel_movies"
run_date = "2026-02-22"
force_refresh = False

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd()
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

# %%
import subprocess
import sys

import pandas as pd

from src.common.io import read_json, update_stage_metrics
from src.common.paths import REPORTS_DIR

subprocess.run([sys.executable, 'scripts/run_dq.py'], check=True)

dq_summary = read_json(REPORTS_DIR / 'dq_result_summary.json', fallback={})
update_stage_metrics('dq_notebook', dq_summary)

pd.DataFrame([dq_summary])
